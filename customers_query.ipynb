# %%
import mysql.connector
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select count(*),gender from customers group by gender"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (7518, 'Female')
# (7748, 'Male')

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select count(customer_key),country from customers  group by country"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (1420, 'Australia')
# (1553, 'Canada')
# (1473, 'Germany')
# (670, 'France')
# (645, 'Italy')
# (733, 'Netherlands')
# (1944, 'United Kingdom')
# (6828, 'United States')

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select c.country,s.currency_code,round(sum(s.quantity*p.unit_price_usd*e.exchange),2) from customers c join sales s on c.customer_key =s.customer_key join products p on s.product_key = p.product_key  join exchange_rates e on e.currency = s.currency_code and e.date_current = s.order_date group by c.country,s.currency_code "
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# ('Germany', 'EUR', Decimal('4775426.14'))
# ('United States', 'USD', Decimal('29871631.17'))
# ('Italy', 'EUR', Decimal('2188970.63'))
# ('Canada', 'CAD', Decimal('6216370.33'))
# ('United Kingdom', 'GBP', Decimal('5449533.23'))
# ('Netherlands', 'EUR', Decimal('1730936.39'))
# ('Australia', 'AUD', Decimal('3779715.78'))
# ('France', 'EUR', Decimal('1336882.43'))

# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select round(sum(s.quantity*p.unit_price_usd*e.exchange),2) from customers c join sales s on c.customer_key =s.customer_key join products p on s.product_key = p.product_key  join exchange_rates e on e.currency = s.currency_code and e.date_current = s.order_date"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (Decimal('55349466.10'),)

# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select c.continent,s.currency_code,round(sum(s.quantity*p.unit_price_usd*e.exchange),2) from customers c join sales s on c.customer_key =s.customer_key join products p on s.product_key = p.product_key  join exchange_rates e on e.currency = s.currency_code and e.date_current = s.order_date group by c.continent,s.currency_code "
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# ('Europe', 'EUR', Decimal('10032215.58'))
# ('North America', 'USD', Decimal('29871631.17'))
# ('North America', 'CAD', Decimal('6216370.33'))
# ('Europe', 'GBP', Decimal('5449533.23'))
# ('Australia', 'AUD', Decimal('3779715.78'))

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select count(*),continent from customers group by continent"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (1420, 'Australia')
# (8381, 'North America')
# (5465, 'Europe')

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select sum(s.quantity),p.brand,p.category from sales s join products p on s.product_key = p.product_key group by p.brand,p.category order by sum(s.quantity) desc"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (Decimal('18764'), 'The Phone Company', 'Cell phones')
# (Decimal('17455'), 'Tailspin Toys', 'Games and Toys')
# (Decimal('14545'), 'Contoso', 'Music, Movies and Audio Books')
# (Decimal('14257'), 'Southridge Video', 'Music, Movies and Audio Books')
# (Decimal('14103'), 'Wide World Importers', 'Computers')
# (Decimal('13483'), 'Adventure Works', 'Computers')
# (Decimal('13006'), 'Wide World Importers', 'Audio')
# (Decimal('12713'), 'Contoso', 'Cell phones')
# (Decimal('8721'), 'Proseware', 'Computers')
# (Decimal('7649'), 'Contoso', 'Home Appliances')
# (Decimal('7264'), 'Northwind Traders', 'Audio')
# (Decimal('6081'), 'Fabrikam', 'Cameras and camcorders')
# (Decimal('5873'), 'Contoso', 'Cameras and camcorders')
# (Decimal('5655'), 'A. Datum', 'Cameras and camcorders')
# (Decimal('5625'), 'Adventure Works', 'TV and Video')
# (Decimal('5136'), 'Southridge Video', 'Games and Toys')
# (Decimal('5085'), 'Contoso', 'Computers')
# (Decimal('4676'), 'Litware', 'Home Appliances')
# ...

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select round(sum(s.quantity*p.unit_price_usd*e.exchange),2) as sale,p.category from customers c join sales s on c.customer_key =s.customer_key join products p on s.product_key = p.product_key  join exchange_rates e on e.currency = s.currency_code and e.date_current = s.order_date group by p.category order by sale desc"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (Decimal('19143319.65'), 'Computers')
# (Decimal('10747777.59'), 'Home Appliances')
# (Decimal('6502487.56'), 'Cameras and camcorders')
# (Decimal('6118492.00'), 'Cell phones')
# (Decimal('5857337.90'), 'TV and Video')
# (Decimal('3147476.96'), 'Audio')
# (Decimal('3113971.62'), 'Music, Movies and Audio Books')
# (Decimal('718602.82'), 'Games and Toys')

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select round(sum(s.quantity*p.unit_price_usd*e.exchange),2),p.brand from customers c join sales s on c.customer_key =s.customer_key join products p on s.product_key = p.product_key  join exchange_rates e on e.currency = s.currency_code and e.date_current = s.order_date group by p.brand"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (Decimal('10727146.78'), 'Contoso')
# (Decimal('1482227.12'), 'A. Datum')
# (Decimal('6801046.53'), 'Fabrikam')
# (Decimal('11732719.56'), 'Adventure Works')
# (Decimal('5328363.66'), 'The Phone Company')
# (Decimal('3239547.32'), 'Proseware')
# (Decimal('9052942.95'), 'Wide World Importers')
# (Decimal('676266.89'), 'Tailspin Toys')
# (Decimal('2558004.78'), 'Southridge Video')
# (Decimal('2638837.14'), 'Litware')
# (Decimal('1112363.37'), 'Northwind Traders')

# %%
cnx = mysql.connector.connect(user = "root",host = "localhost",password ="Savithri@508",database = "dataspark")
cursor = cnx.cursor()
query = "select count(s.customer_key) cust_order,c.customer_name from sales s join customers c on s.customer_key = c.customer_key group by c.customer_name order by cust_order desc"
cursor.execute(query)

myresult = cursor.fetchall()

for x in myresult:
  print(x)

cnx.close()
# Out:
# (36, 'Gaspare Trevisan')
# (32, 'Paul Warren')
# (32, 'Fabrice Lamoureux')
# (30, 'Kyle Quinn')
# (29, 'Margaret Mattson')
# (29, 'Lisa Sherman')
# (29, 'Victor Kristensen')
# (29, 'Claire Macdonald')
# (29, 'Delmer Martinez')
# (28, 'Richard Smith')
# (28, 'Velia Phillips')
# (28, 'Uriele Marcelo')
# (27, 'Maurizia Pirozzi')
# (27, 'Dylan Taylor')
# (27, 'David Breton')
# (27, 'Chad Coon')
# (26, 'Robert Nelsen')
# (26, 'Lillian Evans')
# (26, 'Donald Williams')
# (25, 'Vanessa Holzman')
# (25, 'Cerys Farmer')
# (25, 'Kyle Dixon')
# (25, 'Andrea McMurray')
# (24, 'Irene Cardoza')
# (24, 'Juliane Duerr')
# (24, 'René Fuerst')
# (24, 'Daniel Walton')
# (24, 'Eleanor Jackson')
# (24, 'Edward Rose')
# (24, 'Mark Enloe')
# (24, 'Robert Smith')
# (24, 'Mark Hillman')
# (24, 'Wayne Long')
# (24, 'Sara Christensen')
# (24, 'Tyrone Lewis')
# (24, 'Darci Dorsey')
# (23, 'Frances Colbert')
# (23, 'Essie Scott')
# (23, 'Marcos McMichael')
# (23, 'Marlene Merritt')
# (23, 'Elizabeth Turner')
# ...
